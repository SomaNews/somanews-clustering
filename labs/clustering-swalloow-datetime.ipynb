# %% [markdown]
# # Test script of SomaNews Clustering
# By Datetime : 2016-08-29 ~ 2016-09-05

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Data
# Load Data from database

# %%
train = pd.read_pickle("../datastore/train.p")
train = train.drop(['_id', 'author', 'description', 'link', 'imageURL', 'providerNewsID'], axis=1)
train.head()
# Out:
#             category                                            content  \
# 0          사회 > 카드뉴스  과연 진실은... \n[ 조선일보 카드뉴스가 더 보고 싶다면 ?] \n\n[ 조선일...
# 1          사회 > 카드뉴스  '세기의 연인'이라 불렸던 커플\n\n[ 조선일보 카드뉴스가 더 보고 싶다면 ?] ...
# 2          사회 > 카드뉴스  당신의 목소리는 그 누구의 목소리보다 귀하게 쓰였습니다.  기사보기 : https:...
# 3        문화 > 오늘의 운세  36년생 정도를 지키면 무난한 날. 48년생 결정할 일 결정하도록. 60년생 가뭄에...
# 4  스포츠ㆍ연예 > 스포츠 > 종합
#
#   provider         publishedAt                              title
# 0   chosun 2016-09-21 19:28:00         [카드뉴스] 대통령은 왜 흙을 밟지 않았을까요?
# 1   chosun 2016-09-21 19:10:00              [카드뉴스] '브란젤리나'의 시작과 끝
# 2   chosun 2016-09-21 19:03:00      [카드뉴스] 목소리를 가장 귀하게 쓴 한 성우 지망생
# 3   chosun 2016-09-21 18:00:00  [오늘의 운세] 9월 22일 목요일(음력 8월 22일 丁未)
# 4   chosun 2016-09-21 03:00:00              [오늘의 경기] 2016년 9월 21일

# %%
train = train[pd.to_datetime(train.publishedAt).dt.year == 2016]
train.publishedAt.head()
# Out:
# 0   2016-09-21 19:28:00
# 1   2016-09-21 19:10:00
# 2   2016-09-21 19:03:00
# 3   2016-09-21 18:00:00
# 4   2016-09-21 03:00:00
# Name: publishedAt, dtype: datetime64[ns]

# %% [markdown]
# ## Preprocessing
# 0. Datetime (16-09-11 ~ 16-09-17)
# 1. Remove stopwords (regex, hanja)
# 2. POS Tagging with KoNLPy, Mecab

# %%
import datetime
from konlpy.tag import Mecab
import hanja
import re

# %%
train["newsNum"] = 1

# %%
train.set_index(train['publishedAt'], inplace=True)
train.head()
# Out:
#                               category  \
# publishedAt
# 2016-09-21 19:28:00          사회 > 카드뉴스
# 2016-09-21 19:10:00          사회 > 카드뉴스
# 2016-09-21 19:03:00          사회 > 카드뉴스
# 2016-09-21 18:00:00        문화 > 오늘의 운세
# 2016-09-21 03:00:00  스포츠ㆍ연예 > 스포츠 > 종합
#
#                                                                content  \
# publishedAt
# 2016-09-21 19:28:00  과연 진실은... \n[ 조선일보 카드뉴스가 더 보고 싶다면 ?] \n\n[ 조선일...
# 2016-09-21 19:10:00  '세기의 연인'이라 불렸던 커플\n\n[ 조선일보 카드뉴스가 더 보고 싶다면 ?] ...
# 2016-09-21 19:03:00  당신의 목소리는 그 누구의 목소리보다 귀하게 쓰였습니다.  기사보기 : https:...
# 2016-09-21 18:00:00  36년생 정도를 지키면 무난한 날. 48년생 결정할 일 결정하도록. 60년생 가뭄에...
# 2016-09-21 03:00:00
#
#                     provider         publishedAt  \
# publishedAt
# 2016-09-21 19:28:00   chosun 2016-09-21 19:28:00
# 2016-09-21 19:10:00   chosun 2016-09-21 19:10:00
# 2016-09-21 19:03:00   chosun 2016-09-21 19:03:00
# 2016-09-21 18:00:00   chosun 2016-09-21 18:00:00
# 2016-09-21 03:00:00   chosun 2016-09-21 03:00:00
#
#                                                  title  newsNum
# publishedAt
# 2016-09-21 19:28:00         [카드뉴스] 대통령은 왜 흙을 밟지 않았을까요?        1
# 2016-09-21 19:10:00              [카드뉴스] '브란젤리나'의 시작과 끝        1
# 2016-09-21 19:03:00      [카드뉴스] 목소리를 가장 귀하게 쓴 한 성우 지망생        1
# 2016-09-21 18:00:00  [오늘의 운세] 9월 22일 목요일(음력 8월 22일 丁未)        1
# 2016-09-21 03:00:00              [오늘의 경기] 2016년 9월 21일        1

# %%
weekly_df = train.resample('W-Mon').agg({'newsNum': np.sum}).fillna(0)
weekly_df
# Out:
#              newsNum
# publishedAt
# 2016-01-04       585
# 2016-01-11      1645
# 2016-01-18      1847
# 2016-01-25      2757
# 2016-02-01      2830
# 2016-02-08      2298
# 2016-02-15      1972
# 2016-02-22      2769
# 2016-02-29      2941
# 2016-03-07      2667
# 2016-03-14      2763
# 2016-03-21      2868
# 2016-03-28      2950
# 2016-04-04      2879
# 2016-04-11      2650
# 2016-04-18      2652
# 2016-04-25      2733
# 2016-05-02      2845
# 2016-05-09      2293
# 2016-05-16      2631
# 2016-05-23      2600
# 2016-05-30      2772
# 2016-06-06      2488
# 2016-06-13      2505
# 2016-06-20      2505
# 2016-06-27      2642
# 2016-07-04      2840
# 2016-07-11      2574
# 2016-07-18      2688
# 2016-07-25      2723
# 2016-08-01      2317
# 2016-08-08      2258
# 2016-08-15      2533
# 2016-08-22      2662
# 2016-08-29      2861
# 2016-09-05      3088
# 2016-09-12      2773
# 2016-09-19      1488
# 2016-09-26       993

# %%
dstart = datetime.date(2016,8,29)
dend = dstart + datetime.timedelta(weeks=1)
dend
# Out:
# datetime.date(2016, 9, 5)

# %%
train = train[(train["publishedAt"] > dstart) & (train["publishedAt"] < dend)]
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3068 entries, 2016-09-04 23:28:00 to 2016-08-29 00:51:00
# Data columns (total 6 columns):
# category       3068 non-null object
# content        3068 non-null object
# provider       3068 non-null object
# publishedAt    3068 non-null datetime64[ns]
# title          3068 non-null object
# newsNum        3068 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 167.8+ KB

# %%
mecab = Mecab()
print(mecab.nouns(u'네, 안녕하세요'))
# Out:
# ['안녕']

# %%
def text_cleaning(text):
    text = hanja.translate(text, 'substitution')
    text = re.sub('[^가-힝0-9a-zA-Z\\s]', ',', text)
    text = text.replace("카드뉴스", '')
    return text

# %%
def tokenize(data):
    return [' '.join(str(e) for e in mecab.nouns(data))]

# %%
train['title'] = train['title'].apply(lambda text: text_cleaning(text)).astype('U')
title = [tokenize(each[1]['title']) for each in train.iterrows()]
title
# Out:
# [['전기 저장 년 뒤 억 달러 시장'],
#  ['할인 요금제 기간 년'],
#  ['중국 발 공급 과잉 저유 먹구름 정유 업계 긴장'],
#  ['레고 로봇 스마트 캐디 게임 칫솔 독서 기업'],
#  ['경쟁사 핵심 부품 건 기술력 자신 때문'],
#  ['올해 내 미 사물 인터넷 서비스 단계 타국 확대'],
#  ['영화 예고편 줄'],
#  ['영화 예고편 줄'],
#  ['원자재 값 급등 중규 국내 배 터리사 중고'],
#  ['원자재 값 급등 중규 국내 배 터리사 중고'],
#  ['파업 중 한국 사장 직원 이메일'],
#  ['면세점 덩치 한국 신규 곳 적자'],
#  ['면세점 덩치 한국 신규 곳 적자'],
#  ['보장 보험료 올해 최대'],
#  ['교실 밖 아이 선생 질문'],
#  ['배달 앱 프랑스 요리 부심'],
#  ['오늘 운세 월 일 월요일 음력 월 일 경인'],
#  ['미래 첨단 무기 웨어 러블 로봇 주요 기술 확보'],
#  ['차세대 무기 체계 레이저 무기 투자 집중'],
#  ['국내 최대 규모 지상군 전시회'],
#  ['천 년 고도 경주 사극 세트 장'],
#  ['소년 세 생일 축하 편지'],
#  ['아가 네 세상'],
#  ['다운 증후군 종업원 은퇴 파티'],
#  ['투견 눈물'],
#  ['사설 방어 무기 하나 달 소란 정국 마비 나라'],
#  ['사설 이번 서경배 억 줄 기업 노블레스 오 블리 주'],
#  ['사설 재벌 오너 이름 수십억 연봉'],
#  ['만물상 퇴비 냄새'],
#  ['박성현 공동 선두'],
#  ['터치 코리아 당신 애정 취약 계층 이 십'],
#  ['트렌드 돋보기 이화'],
#  ['가슴 한시'],
#  ['이미도 무비 식도'],
#  ['조선 주말 하이라이트 모란봉 클럽 외'],
#  ['조선 추석 준비 법'],
#  ['조선 남자 인생'],
#  ['윤성호 허정구 배 아마추어 골프 련패'],
#  ['라운드 홀인원 개'],
#  ['오늘 경기 년 월 일'],
#  ['미 시 풋볼 선수 이번 돼지 양말 논란'],
#  ['내일 경기 년 월 일'],
#  ['스포츠 브리핑 강정호 재활 경기 홈런'],
#  ['정신줄 수비 고질병'],
#  ['지참 대표 팀 해동'],
#  ['홈 일본 축구 패닉'],
#  ['두산 오재일 끝 내기 안타'],
#  ['야구 여인'],
#  ['팔 면봉 여 정기 국회 시작 추가경정예산 처리 외'],
#  ['만두 군 여름 누진세'],
#  ['적 친구 돈 까스 맛 기억'],
#  ['세계 베스트셀러 프랑스 해리포터 마지막 열광'],
#  ['결혼 사랑 열정 기술 걸'],
#  ['북카페 것 외'],
#  ['삼류 연애 시인 사랑 듯'],
#  ['편집자 레터 에스프레소 커피 에스프레소 책'],
#  ['오늘 사우디 붕괴 직전 소련'],
#  ['어린이 책 피라미드 아우슈비츠 수용소 공통점'],
#  ['모두 관심 하나 사랑'],
#  ['임진왜란 국교 재개 교토 일교 류사'],
#  ['줄 금난새 오페라 여행 외'],
#  ['남자 상어 항해 바다 위 꿈'],
#  ['배상근 경제학 책갈피 아이 일자리 외국어 대신 기술'],
#  ['당신 리스트 작가 호원숙 이별 추억 책'],
#  ['흙장난 아이 건강'],
#  ['당신 운명 사랑'],
#  ['성장 주사 우리 아이 키'],
#  ['가을'],
#  ['영화 관서 짜장면 국밥 떡볶이 푸드 코트 줄'],
#  ['수 어둠 속 고백'],
#  ['카리모프 우즈베키스탄 대통령 사망설'],
#  ['난민 엄마 메르켈 가을'],
#  ['노르웨이 왕실 근위대 아문센 영 기증 펭귄 후손 준장 진급 식 에든버러 동물 원서 대'],
#  ['강인선 워싱턴 오하이오 쇠락 마을 트럼프 오자 열광 백인 스트레스 클린턴 욕'],
#  ['남미 좌파 붕괴 도미노 베네수엘라 마두 대통령 탄핵 요구 규모 시위'],
#  ['월드 문신 일 온천'],
#  ['급 전략 폭격기 개발 중 중 공군 사령관 공식 확인'],
#  ['테르 테 반기문 총장 회담 요청 거절'],
#  ['걸 그룹 주사 피부 함몰 윤곽 주사 성분'],
#  ['플라자 한국 문학 교육 학회 창립 주년 기념 학술 대회 개최 외'],
#  ['부음 권덕준 별세 외'],
#  ['인사 이기우 한국 전문 대학 교육 협의 회장 외'],
#  ['노래방 비명 스트레스'],
#  ['트럼프 아내 멜라니아 성 접대'],
#  ['세 한글 공부 시작 시 최우 수상 만학도'],
#  ['국악 한류 허윤정 서울대 교수 임용'],
#  ['영어 약속 미 화장품 회사 성공'],
#  ['안전벨트 시민 도움 아이'],
#  ['이진희 날씨 레터 균형'],
#  ['오늘 날씨 년 월 일'],
#  ['남부 동해 태풍'],
#  ['롯데 신동주 횡령 부인 오너 경영 역할'],
#  ['레인지 로버 부장 판사 구속 대법원 반성'],
#  ['강만수 특혜 대출 개입 의혹 한성 기업 압수수색'],
#  ['서초동 시 고뇌 김수남 김밥 줄 산행'],
#  ['국가 대표 선발 등 억 뒷돈 수영 연맹 전 간부 징역 년'],
#  ['구파발 실탄 사고 경찰 심서 살인죄 인정'],
#  ['육아 상경 할머니'],
#  ['정조 능행 차 년 만 재현'],
#  ['말 벌주 사람'],
#  ['신궁 뒤 딸 바보 아버지'],
#  ['대형 포털 스타트업 아이디어 걸까'],
#  ['합숙 취업 캠프 밤 시 일 끝'],
#  ['마약 내 이웃 중독자 수'],
#  ['통일 펀드 동참'],
#  ['출국 길 박 대통령 북 내부 상황 우려'],
#  ['항저우 내일 개막 중 변국'],
#  ['박 대통령 북 핵 제거 사드 필요'],
#  ['청 김재수 조윤선 임명 법대 것'],
#  ['북 중'],
#  ['북 혁명 성지 양강 북 중심지'],
#  ['속 국민 당'],
#  ['사드 발언 오버 정의 장'],
#  ['광주 지도부 대선 주자'],
#  ['대야 주먹 소여'],
#  ['국회 정상 서청원 의원 막후 역할'],
#  ['분열 땐 위기감 속 박 비박'],
#  ['야 힘 자랑 여 몸 저항 대 국회 압축 판'],
#  ['남미 최경환 포퓰리즘 경계'],
#  ['독일 안철수 선진 경제'],
#  ['유커 의존 관광 역풍 수'],
#  ['우리 나라 여행 거기 거기 바가지 해외'],
#  ['뭐 말 초 휴가철 분산 국내 관광지'],
#  ['해운 일단락 수주 절벽 조선 게임'],
#  ['조선 구조 조정 파도'],
#  ['노트 만 대 전량 교환 삼성 리콜 총비용 조원대'],
#  ['라가르드 경고 세계 경제 저성장 덫 수'],
#  ['노트 오늘 대리점 환불 기종 교체 가능'],
#  ['강천석 칼럼 지도 나라 명심 일'],
#  ['자폐 아이 밥 유일 스타'],
#  ['오늘 운세 월 일 일요일 음력 월 일 기축'],
#  ['오늘 운세 월 일 토요일 음력 월 일 무자'],
#  ['집 회사 더위 직장 아이템'],
#  ['이번 알리바바 클라우드 사업'],
#  ['소비 절벽 파업 이중고 현대 기아차 월 국내 판매량 급감'],
#  ['삼성카드 발행 주식 달 자 사 주 매입'],
#  ['건 일본 선진 운전 문화'],
#  ['피아니스트 백 건우 선물'],
#  ['애플 조 원 세금 폭탄 까닭'],
#  ['사설 정기 국회 첫날 오기 대결 나라 걱정'],
#  ['사설 생산 소비 투자 동반 감소 누가 고민'],
#  ['사설 서울시 사업 뭔가 듯'],
#  ['박정훈 칼럼 야당 정체 정체'],
#  ['만물상 간염'],
#  ['태평로 길 빚 지탱 성장'],
#  ['프리즘 아베 마리오 올림픽'],
#  ['객원 기자 칼럼 김정은 직면 대 위기'],
#  ['가슴 시조 추청 추청'],
#  ['독자 칼럼 의식 불명 택시 기사 방치 사망'],
#  ['아침 편지 타계 년 아버지 홍난파 생각'],
#  ['고랭지 감자 평창'],
#  ['독자 제언 전기 요금 개편 꼼수'],
#  ['독자 마당 엘리트 체육 정책 재고'],
#  ['독자 마당 부산 락 페스티벌 음식 판매 횡포'],
#  ['독자 마당 어린이 교통 카드 등록'],
#  ['독자 마당 지방 정부 표현'],
#  ['정약용 제작 무산 대하 사극 명맥'],
#  ['조선 분가 성공 김영희 부부'],
#  ['이번 주 개봉 영화 자평 머니 몬스터 외'],
#  ['한국 영화 아카데미 십 세전'],
#  ['허정구 배 아마추어 골프 대회 윤성호 김동민 결승 맞대결'],
#  ['회 배 조선일보 기왕 전 초반 실험'],
#  ['혼 밥 자폐 소년 친구 풋볼 선수'],
#  ['오늘 경기 년 월 일'],
#  ['중국 축구'],
#  ['한국 시리아 전 말레'],
#  ['내년 월 경기 상위 팀 월드컵 직행'],
#  ['빵 군 만 명 중국인 골 담배'],
#  ['니퍼트 통산 번 완 봉승 박용택 년 연속 안타'],
#  ['현수 번'],
#  ['댕이 대호 복수'],
#  ['일 교육부 성희롱 수뢰 공무원 피신처 국립대 기사'],
#  ['신문 선생 알 립니 현직 기자 강의 월 강좌 다음 주 시작 외'],
#  ['일사일언 남산'],
#  ['팔 면봉 대 정기 국회 개막 날 국회 의장 발언 정파 논란 파행 외'],
#  ['불안 현실 예술 미래'],
#  ['명절 가족 품격 한잔'],
#  ['한국인 체형 연령 맞춤 매트리스'],
#  ['아내 피부 탄력 여자 친구 꽃향기'],
#  ['다이얼 선명 라인 뉴욕 브로드웨이 연상'],
#  ['미니 멀 클래식 디자인 여성미'],
#  ['런던 자유분방 보헤미안 감성'],
#  ['손목 예술 일상 특별'],
#  ['뿐 가을 스타일 완성'],
#  ['무심 듯 시크 액세서리 하나 세련 남성'],
#  ['꽃길 게요'],
#  ['방수 자동 수평 보정 방위 계측 아웃도어'],
#  ['가방 개 최소 시간 수작업 장인 손 탄생 명품'],
#  ['캡틴 아메리카 방패 아이언맨 셔츠 히어로'],
#  ['특유 셰브런 패턴 심'],
#  ['송광사 오불 제자리'],
#  ['순교자 곳 그 넋 위로 사중주'],
#  ['빈자 성녀 사랑 눈앞 사람'],
#  ['조선 총독 호통 스님 아시나'],
#  ['종교 소식 서울 가톨릭 사회 복지 회 주년 행사 외'],
#  ['시성식 바티칸 생중 국내선 일 시성 감사 미사'],
#  ['가봉 봉고 대통령 재선 부자 반세기 집권'],
#  ['영국 반 이슬람 확산 부르카 금지 여론'],
#  ['무능 부패 포퓰리즘 정권 몰락 남미 좌파 벨트 치명타'],
#  ['멕시코 트럼프 이용'],
#  ['호세프 탄핵 주도 동반자 배신자'],
#  ['브라질 년 좌파 정권 경제 파탄'],
#  ['멕시코 트럼프 친구 관용'],
#  ['호세프 위헌 소송'],
#  ['아베 푸틴 초청 료칸 외교'],
#  ['후진타오 법률 고문 샤 융 국가 기밀 유출 혐의 체포'],
#  ['뇌 운동 문장 꽈배기'],
#  ['리빙 포인트 벽지 얼룩'],
#  ['플라자 림 선진 인재 양성 글로벌 일류 대학 비전 선 포식 개최 외'],
#  ['부음 박성연 별세 외'],
#  ['인사 교육부 외'],
#  ['직지 한국 서명 운동 미국인'],
#  ['박인비 기부 챔피언'],
#  ['드니 퀘 게 서울평화상'],
#  ['이영애 육군사관학교 억 쾌척'],
#  ['웰빙 게 남 도움 삶'],
#  ['발자취 역전 점 홈런 가을 야구 롯데 전설'],
#  ['장강명 오늘 작가'],
#  ['주형 배 현정 씨 일 가상'],
#  ['한승수 총리 중 어판 연설 문집 출간'],
#  ['구세군 캄보디아 어린이 심장병 수술 지원'],
#  ['무림 고수 청주서 한판'],
#  ['국민연금 저소득층 만 명 가입 가능'],
#  ['철도 화물 적자 요금'],
#  ['사건 블랙박스 저축 비리 그 옥중 자살 시도'],
#  ['오늘 날씨 년 월 일'],
#  ['중국어 한마디 게 어디'],
#  ['입 일본어 태반 차지'],
#  ['신문 실용 자 감탄고토 감탄고토'],
#  ['스피킹 영어'],
#  ['월 모의 평가 국어 변별력 수학 영어'],
#  ['년 무역상 속 아프리카 유산 사 기단'],
#  ['검찰 신동주 일 억 급여 횡령죄 논란'],
#  ['집 운전자 음주 측정 요구 위법'],
#  ['복대 외화 해외 억 밀반출'],
#  ['부장 판사 수뢰 꽃놀이패 골탕 먹이 법원 검찰 글'],
#  ['이인복 대법관 퇴임 법원'],
#  ['중고품 거래 사기 맘 대 남성'],
#  ['땅 땅 오늘 판결 차 것 명함 뺑소니'],
#  ['책 동굴 여행'],
#  ['발 칼 급증 폭주 노인'],
#  ['정상 선물'],
#  ['추석 전통 시장 주변 최대 시간 주차 허용'],
#  ['줄 뉴스 건국대 충주 병원 간염 명 발생 외'],
#  ['노조 출범 움직임 전교조 사드 투쟁'],
#  ['사드 배치 중 전문가 격론'],
#  ['통일 펀드 동참'],
#  ['박 대통령 시진핑 사드 정상 회담'],
#  ['김천 주민 대표단 국방 면담 부지'],
#  ['일 간 정기 국회 대선 곳곳 지뢰밭'],
#  ['병우 거론 땐 공수 처 웅성 사드 폭발'],
#  ['김종인 사과 추미애 고견'],
#  ['당 대표 복당 문제 자리 박 최고 위원'],
#  ['시중 금리 일 때 농협 대 특혜 대출'],
#  ['문재인 김부겸 안희정 출마 선언 환영'],
#  ['기권 설 일축 링 위 박원순'],
#  ['안철수 지난달 일 손학규 단독 회동'],
#  ['정세균 병우 사드 발언 여 정기 국회 첫날 보이콧'],
#  ['퇴비 냄새 이해찬 한마디'],
#  ['조윤선 청문회 파행 청 임명 진행 듯'],
#  ['프랑스 장인 손길 무쇠 냄비 손맛'],
#  ['명절 선물 품격 실속 번'],
#  ['러시아 녹용 꿀 아이 입맛 부담'],
#  ['미 서부 한진 화물 수송 스톱'],
#  ['외국인 관광객 서울 강북 도심'],
#  ['도쿄 영어 일본 산골 마을'],
#  ['영어 지방 여행 탐험'],
#  ['삼성전자 갤럭시 노트 전량 리콜'],
#  ['한진 미 유럽 노선 현대 상선 선박 척 투입'],
#  ['한진 해운 동맹 퇴출 배 글로벌 사도 타격'],
#  ['몸값 광화문 상권 거품 종각 상권'],
#  ['삼성 고화질 프리미엄 승부수'],
#  ['삼성 고화질 프리미엄 승부수'],
#  ['생산 인구 감소 부동산 차 철강 도미노 타격'],
#  ['아톰 소년 억 과학 재단'],
#  ['오늘 운세 월 일 금요일 음력 월 일'],
#  ['전자 소음 진동 가전 유럽 공략'],
#  ['현대차 파격 세일즈 쏘나타 맘 그랜저 수'],
#  ['한국 대학 지 년'],
#  ['자리 내 아이'],
#  ['미국 최대 공항 곳 마비 것'],
#  ['사설 자세 불량 이 처형 김정'],
#  ['사설 조선일보 음모 공식 입장 청와대'],
#  ['사설 일자리 기업 시대 수'],
#  ['만물상 맥주 맛'],
#  ['김대식 브레인 스토리 현실 진실 차이'],
#  ['동서남북 중국 좌파 오리엔탈리즘'],
#  ['기고 한국 관광 산업 돈 작정 건가'],
#  ['기자 시각 사마리아인'],
#  ['현우 팝 컬처 코미디언 시대'],
#  ['노트 폭발 주장 삼성 국내 공급 일시 중단'],
#  ['포럼 중앙 부처 동네북 읍 면 동'],
#  ['윤희영 에디슨 기록 학점 학생 출신 발명가'],
#  ['양해원 말 글 탐험 우리 말 서식 황소개구리'],
#  ['발언 대 잡 노 마드 중남미'],
#  ['한마디 무성의 소비자 상담 센터'],
#  ['김치 장면 번'],
#  ['조선 자금 최민수'],
#  ['허정구 배 골프 윤성호 강 진출'],
#  ['바람 렉시 톰프슨 태안'],
#  ['회 배 조선일보 기왕 전 시대'],
#  ['스포츠 브리핑 허재 감독 남자 농구 팀 튀니지 승 외'],
#  ['오늘 경기 년 월 일'],
#  ['주년 춘천 마라톤 준비 특별 선물'],
#  ['추석 요정'],
#  ['선수촌 몰카 파문 수영 대표 팀 감독 사퇴'],
#  ['월드컵 대표 팀 일 시리아 전 마카오 개최 취소'],
#  ['해커 덕분 해피'],
#  ['오승환 회 말 등장 팀'],
#  ['한국 미국 곰 왕'],
#  ['일사일언 아버지 수술'],
#  ['팔 면봉 문화부 장관 인사 청문회 여당 퇴장 채 진행 외'],
#  ['백건우 연주 여러분 신청 곡'],
#  ['남성미 순수 듯 올페'],
#  ['임방울 국악진흥회 대구 공연'],
#  ['거장 판두 르 유작 파우스트 서울'],
#  ['트렌드 늑대인간 과학자 전략가 남자 일 필요'],
#  ['차이콥스키 콩쿠르 우승자 마슬 예프 피아노 독주회'],
#  ['한국학 중앙 연구원 한옥'],
#  ['시각 태평 무 인간 문화재 개월 만 원점 원칙 문화재 행정'],
#  ['테러 피라미드 방문객 분 토막'],
#  ['좌파 정부 시장 대 장관 대선 출마 사임 호감 위'],
#  ['캐나다 중국 주도 가입 공식 표명'],
#  ['트럼프 장벽 멕시코 간다'],
#  ['일 호 태풍 폭우 하룻밤 노인 명'],
#  ['늑대 선동 인자 공습 사망'],
#  ['뇌 운동 신문 스케치북'],
#  ['리빙 포인트 욕실 비누'],
#  ['거제 번 콜레라 창선 집단 간염 의심'],
#  ['플라자 과학 기술 사회 실현 국민 연합 차 오픈 포럼 개최 외'],
#  ['부음 권 덕 별세 외'],
#  ['인사 황주호 한국 원자 력학 회장 취임 외'],
#  ['김말애 대한민국 예술 원상'],
#  ['김시홍 장 모네 학술'],
#  ['에베레스트 등정 허위 발표 인도 부부'],
#  ['군 복무 낭비 하프타임'],
#  ['행려병자 수녀 등 서울시 명예 전당'],
#  ['인천 상륙작전 노병 년 만 인천'],
#  ['프랑스 사진가 마르크 리부 별세'],
#  ['영웅 몽클 라르 장군 추모 유품 사진 전'],
#  ['경기도 생활 임금 만 원'],
#  ['지하철 출입구 이내 흡연 땐 과태료 만 원'],
#  ['단독 바퀴 서울 개 구간'],
#  ['오늘 날씨 년 월 일'],
#  ['더위 최고 기온 도'],
#  ['중국어 한마디 기분 전환'],
#  ['입 일본어 차'],
#  ['신문 실용 자 천리마 천리마'],
#  ['스피킹 영어'],
#  ['교육부 성희롱 수뢰 공무원 피신처 국립대 정정 내용'],
#  ['포스 텍 기업 추천 인력 교수 채용'],
#  ['의대 때 인성'],
#  ['포스 텍 내년 신입 무학과 선발'],
#  ['롯데 경영 신격호 이상'],
#  ['레인지 로버 부장 판사 소환 조사 법원 행사 취소'],
#  ['검 롯데 장남 신동주 오늘 소환'],
#  ['진경준 막자 검찰 특별 감찰'],
#  ['세월 호 유족 너 때문 남편 굿판 억대 무속'],
#  ['박수환 뉴 스컴 대표 거래 효성 차남 회사 압수수색'],
#  ['어버이 연합 관제 시위 의혹 현준 청 행정관 소환 조사'],
#  ['박원순 용산 공원 반쪽 미군 시설 이전'],
#  ['케이블카 규제 지 달 곳 제자리'],
#  ['중개료 대학생 자취방 직거래'],
#  ['통일 펀드 동참'],
#  ['일본 위안부 재단 억 엔 송금 피해 할머니 명 억 원 수령 거부'],
#  ['한중 미 정상 회담 듯'],
#  ['나 김정은 단두대 정치'],
#  ['북 김영철 실적 서약 도발 가능'],
#  ['북 급증 북 여성 국경 교화소 확장'],
#  ['국민 당 월 만 원 아동 수당 추진'],
#  ['친 당선 탄핵 과거 극복 추 봉하 마을 눈물'],
#  ['여 의원 누리 예산 야단 독 표결 항의 퇴장 조윤선 청문회'],
#  ['여 본회의 추경 처리'],
#  ['몸 안희정 친문 거리'],
#  ['멍텅구리 막말 조청 문회'],
#  ['안철수 일 냉면 회동'],
#  ['입점 개통 삼성역 분'],
#  ['피트 니스 룸 야외 수영장 옥상 정원 미군 라이프 스타일 고급 렌탈 주택'],
#  ['광역철도 신 안산선 내년 착공 가시 주변 부동산 주목'],
#  ['남부터미널역 도보 분 삼성 롯데 타운 등 개발 호재'],
#  ['권리금 신축 점포 냉난 방기 무상 설치'],
#  ['선호 고잔 도시 랜드마크 안산선 개통 땐 최대 수혜 지역 것'],
#  ['수익 단독 주택 세대 호텔 수준'],
#  ['오늘 조선 경제 부장 티 샷 비거리 까닭'],
#  ['물건 으름장 쇼핑 쇼핑 게 비지떡 여행'],
#  ['하루 쇼핑 번 한국인 유커 바가지'],
#  ['일 간 쇼핑 번 짝퉁 가게'],
#  ['팁 쇼핑 제주 만 명 양심 투어'],
#  ['중 전담 여행사 단속 절반 탈세 등 위법 행위'],
#  ['관광 한국 마이너스 투어'],
#  ['신형 폰 고가 부담 보조금 제약 실속파 중고 폰 구매'],
#  ['제휴 카드 스마트폰 통신비 월 만 만 원 할인'],
#  ['국내 스피커'],
#  ['어디 결제 패션 기어'],
#  ['철강업 뼈 구조 조정 중 남 품질 가격 승부'],
#  ['일 호랑이 굴 포스코'],
#  ['오늘 운세 월 일 목요일 음력 월 일 병술'],
#  ['여국 명 참가 세계 대 문화 총회 개최 셈'],
#  ['기록 독립 투명 제고 계기'],
#  ['삼성 구글 산업 전 참가 국새 등 체험'],
#  ['인류 기억 세계기록유산 한국 건 아시아 최다'],
#  ['우수 한국 기록 문화 전자 정부 노하우 나라 공유 기회'],
#  ['국가 기록원 억 건 이상 기록물 보존 수 시설 곳'],
#  ['서울 학술회의 논문 편 발표 디지털 관련'],
#  ['현안 전자 기록 관리 체계 고도'],
#  ['안전 신속 비약 개선 수명 조작 위험'],
#  ['유엔 전자 정부 평가 한국 회 위 달성'],
#  ['직장 서울대 졸업식 축사'],
#  ['원자력 잠수함 필요'],
#  ['국내 최대 복합 시설 판교 알파 돔 시티 첨단 시스템 구축'],
#  ['중 응원단 상암 상륙작전'],
#  ['삼성 헝가리 전기차 배터리 공장'],
#  ['사설 언론 개인 일탈 권력 비리 보도'],
#  ['사설 청와대 낙하산 바깥 눈치'],
#  ['사설 학생 수 교육 예산'],
#  ['조선 칼럼 자긍심 민족 국가 미래'],
#  ['만물상 올여름 일본'],
#  ['정민 세설신어 반고 반고'],
#  ['동서남북 평창 유산'],
#  ['경제 포커스 구조 조정 연내 끝'],
#  ['기자 시각 헬 조선 진짜 탈출구'],
#  ['중동 천일야화 베일 르'],
#  ['김기봉 히스토리아 쿠오바디스 인문학 진흥 법 거 기대'],
#  ['취업 문 채용 규모'],
#  ['청년 일자리 전력투구 조 억'],
#  ['공항 홍대 공항 환승 시간'],
#  ['김명환 시간 여행 년 전 상어 지느러미 비료 원료 수출 가격 국내 소비 전면 금지'],
#  ['사랑 이별 초콜릿'],
#  ['발언 대 전매 금지 강화 청약 개편'],
#  ['가슴 동시 수련 밭'],
#  ['조선 북 고위 간부 북 내막'],
#  ['허정구 배 골프 첫날 차 강호 위'],
#  ['회 배 조선일보 기왕 전 완벽 승국'],
#  ['이번 시 맨'],
#  ['오늘 경기 년 월 일'],
#  ['아이스하키 아시아 리그 안양 한라 개막 연승'],
#  ['메시 은퇴 일 아르헨티나 대표 팀 복귀'],
#  ['한국 등 번호 훈련 중국'],
#  ['테임즈 뒤 가을 추격자 정로 환'],
#  ['오승환 시즌 세이브'],
#  ['요즘 괴물 산체스'],
#  ['스포츠 브리핑 청소년 야구 대표 팀 필리핀 승'],
#  ['일사일언'],
#  ['팔 면봉 문재인 안철수 제 부산 대선 의식 일정 외'],
#  ['도 오프로드 액셀 맛'],
#  ['차승원 베컴 가을 수염 수염'],
#  ['제주 이주 빛 빚'],
#  ['제주 시골 백화점 대형 서점 이 주 초기 마을 행사 적극 참여'],
#  ['그림 패셔 스타 옷'],
#  ['제주 살 수'],
#  ['제주 수 풍석 박물관 인류 공동 소장품 물 바람 돌 전시 최소 박물관'],
#  ['대한민국 뷔페 전쟁'],
#  ['떡볶이 해산물 초밥 만 만 원 제한'],
#  ['폐교 잡지 왕국 회사 미술관'],
#  ['잡지 작품 문화 감식'],
#  ['파크뷰 베이징 오리구이 본토 중국인 지척 아리아 라이브 스테이션 개 라세 느 아시아 음식 강화'],
#  ['랍 스터 송로 버섯 캐비아 푸아그라 때'],
#  ['경쟁 제주 서울 대치동 학원 열풍'],
#  ['멋 섬 년 만 여성복 브랜드 래트 바이티 출시'],
#  ['박정배 한식 탄생 가을 살 내장 젓갈'],
#  ['스펀지 케이크 위 크림치즈 한국 티라미수 엉터리'],
#  ['듯 듯 원목 도마'],
#  ['한국 고위 자리 자기 훈련 결여 천민'],
#  ['탕녀 현모양처 대명사 당신 여자'],
#  ['맥 문화 년 대'],
#  ['년 만 후속 출간 현대 시조 인선'],
#  ['년 역사 유적 해외 전문가 속도전 발굴 우려'],
#  ['경주 산하 기관 민간 발굴 업체 천 년 왕경 플랜'],
#  ['유적지 테마파크 경주 세계유산 해제 수'],
#  ['한국 고대사 시민 강좌 후반기 월 일 개강'],
#  ['유럽 최대 조 원 세금 폭탄 애플'],
#  ['미 인권 북 해외 노동 돈줄 차단'],
#  ['미 대선 해킹 러시아 발 공격 추정'],
#  ['호소 눈물 참고 벼랑 끝 호세프 최후 변론'],
#  ['위구르 독립 주의자 소행 중대 사관 자폭 테러'],
#  ['중 뒤 칼 인도 국경 미사일 기 배치'],
#  ['월드 일 교도소 고령 간호 인력 명'],
#  ['오바마 테르 테 인권 침해 우려 전 듯'],
#  ['뇌 운동 칼럼'],
#  ['리빙 포인트 부엌 욕실 때'],
#  ['플라자 한국 교통 연구원 정책 토론회 개최'],
#  ['부음 김선 돈 씨 별세 외'],
#  ['인사 고용 노동부 외'],
#  ['세 시작 세 육상 퀸 할머니'],
#  ['흡연 개인 문제 사회 재난'],
#  ['마라도나 년 만 너 내 아들'],
#  ['배기동 국립 박물관 문화 재단 이사장'],
#  ['김홍주 백 중앙 의료 원장'],
#  ['차기 유엔 사무총장 구테 헤스'],
#  ['황선우 센터 장 서울 의대 발전 기금'],
#  ['힐러리 측근 애버딘 성 추문 남편 삼진 아웃'],
#  ['추암 촛대바위'],
#  ['시화 매립지 세계 정원'],
#  ['교차로 차선 땐 분홍 선'],
#  ['기업 직원 월급 년 만 마이너스'],
#  ['다뉴브강 곳 역사 예술'],
#  ['신분당선 년 신사역 연장 개통'],
#  ['북 지상 배치 가능 한국 사드 포대 개 필요'],
#  ['옥바라지 강도 살인 무기수 공범 편지'],
#  ['사건 블랙박스 병원 비밀번호 해킹 초짜'],
#  ['강남 패치 뒤 기업 회장 외손녀 질투'],
#  ['전국 태풍 급 비바람'],
#  ['오늘 날씨 년 월 일'],
#  ['중국어 한마디 내'],
#  ['입 일본어 대자 자다'],
#  ['신문 실용 자 비책 비책'],
#  ['스피킹 영어'],
#  ['수능 년 월 일'],
#  ['이인원 장례 마무리 롯데 수사 재개'],
#  ['인분 교수 징역 년 확정'],
#  ['대법 진주 의료 원 폐업 위법 취소'],
#  ['수사 논란 차명 화성 땅'],
#  ['이호진 전태 광 회장 횡령 대상 판단'],
#  ['운전자 명 중 명 운전 내비 조작'],
#  ['박근혜 의원 시절 보좌관 정 윤회 강원 횡성 농지 평'],
#  ['박종인 땅 사 년 전 청령포 일'],
#  ['독자 여러분'],
#  ['외국인 학생 만 명 만 수업'],
#  ['운전 중 내비 조작 한국 범칙금 만 원 영국 최대 만 원'],
#  ['통일 펀드 동참'],
#  ['개국 의원 참여 단체 서울 북인 규탄'],
#  ['우크라 북한 비자 면제 협정 파기'],
#  ['김부겸 문재인 대세 대선 출마 선언'],
#  ['여 민생 예산 부실 예산 예산안 국회 통과 가시밭길'],
#  ['의원 체포 특권 이번'],
#  ['통도사 스님 북 핵 개발 난리 걱정 문재인 사드 최후 수단 최선'],
#  ['출처 의혹 김진태 청 검경 국정원'],
#  ['분권 대통령 양원제 대화 문화 아카데미 개헌안'],
#  ['지병 암 심사 가지 통과 가입'],
#  ['대 주요 질병 보험료 갱신 세 보장'],
#  ['공공 기관 최다 품질 명장 보유 국제 품질 대회 수상 성과'],
#  ['중세 시대 향기 낭만 도시'],
#  ['주식 종목 투자 인공지능 분석'],
#  ['사진 사랑방 후지필름 스튜디오 소통 사진 문화 것'],
#  ['카메라 가능 도전'],
#  ['눈앞 것 풍경 컷'],
#  ['년 기술력 최고 화질'],
#  ['색'],
#  ['최고 눈 환상 배경'],
#  ['카메라 뭘 미러 리스'],
#  ['도 회전 것 가능 세계'],
#  ['스피드 미니 사이즈 당신 선택'],
#  ['풀 프레임 카메라 전설 전문가 아마추어 만족 캐논 명기'],
#  ['방진 방습 방한 빛 번 짐'],
#  ['얼굴 피사체 자동 초점 피부 효과 기능'],
#  ['카메라 이름 속 비밀'],
#  ['고화질 실현 풍경'],
#  ['파나소닉 액션 캠'],
#  ['누구 사진 놀이터'],
#  ['손끝 사진 세계 초보자 실패'],
#  ['반딧불 빛 암흑 속 선명'],
#  ['번 컬쳐 프로젝트 나 사진'],
#  ['자유 중계 액션 캠 대세'],
#  ['소니 액션 캠'],
#  ['프리미엄 버거 고급 커피 종합 외식 업체 도약'],
#  ['시장 가치 공유 진화 브랜드'],
#  ['포장 이사 입주 청소 정리 수납 토털 홈 케어'],
#  ['독자 매칭 시스템 만 명 결혼 성사'],
#  ['에너지 빈곤 써니 프로젝트 운영'],
#  ['물줄기 구강 세정 잇몸 건강 도움'],
#  ['와이즈 넷 홈 카메라 레드 도트 디자인 어워드 수상'],
#  ['최적 영양 배합 뉴 트리 션 포뮬러 출시'],
#  ['중 금리 당일 대출 금융 취약 계층 서민 금융'],
#  ['등록 센서스 도입 인구 주택 총조사 통계 품질'],
#  ['불법 수입 물품 통관 차단'],
#  ['우리 기준 당신'],
#  ['국내 컬러 강판 시장 위 독주'],
#  ['동화 속 마을 이곳'],
#  ['전통 누룩 천연 효모 빵 열풍'],
#  ['관 대명사 수명 년 피즈 수도관 개발'],
#  ['브랜드 격차 차별 마케팅 등'],
#  ['국가 브랜드 경쟁력 지수'],
#  ['진화 기술 시장 혁신'],
#  ['출시 년 만 만 세트 판매 단일 교구 최다'],
#  ['개 독립 모터 사람 손 마사지'],
#  ['첨단 시공 단독 주택 합리 관리비 안심 보안 실현'],
#  ['일평균 구인 만 건 대한민국 대표 취업 포털'],
#  ['유커 명 단체 유치 세계 이목 집중'],
#  ['인테리어 내장재 연구 년 맞춤 제품 인기'],
#  ['신탁 운용 년 노하우 상품 선'],
#  ['월 소득 만 원 이하 신혼 부부 행복 주택 최대 년 거주 가능'],
#  ['예산 감소 폭 역대 최대'],
#  ['조 조 복지 예산 경기 실탄'],
#  ['나랏빚 급증 앞 거 정부'],
#  ['한진 해운 법정 관리 사망 선고 대마불사'],
#  ['국내 위 한진 해운 법정 관리'],
#  ['예산 조 시대 미래 투자'],
#  ['아이폰 내달 일 공개 위기 애플 구'],
#  ['오늘 운세 월 일 수요일 음력 월 일 을유'],
#  ['해 조 투입 미 취득 특허 건수 년 연속 위'],
#  ['대 사료 아미노산 체제 구축 세계 최초 기업'],
#  ['태양광 전환 효율 분기 연속 흑자 기록'],
#  ['필요 포장 기능 노 브랜드 매출 배'],
#  ['필수 인재 년 간'],
#  ['중앙 연구소 규모 배 바이오 등 미래 식품 연구'],
#  ['위기 돌파 답'],
#  ['실용 연구 개발 뇌전증 신약 승인'],
#  ['증강 현실 플랫폼 세계 주목'],
#  ['너 공부 사람 배달'],
#  ['자동차 강판 세계 시장 점유'],
#  ['년 친환경 차 라인업 차종 이상 세계 시장 위'],
#  ['협력 사 물품 대금 조 억 조기 지급'],
#  ['하반기 취업 시즌 시작 기업 채용 설 명회 박람회'],
#  ['피자 집 앞 선 대통령 아저씨'],
#  ['대입 수시 입학 전형 천 대 동덕 여대'],
#  ['해수부 세월 호 선체 인양 후 객실 분리 실종자 수습'],
#  ['오늘 날씨 년 월 일'],
#  ['사설 박 대통령 문 전 대표 국정 어디'],
#  ['사설 기자 압수 수색 우 수석 처 땅 보도 보복'],
#  ['사설 퇴출 위기 한진 해운 합병 검토'],
#  ['김대중 칼럼 우리 언제 방어 것'],
#  ['만물상 년 개띠'],
#  ['태평 한국 물 외국 기업'],
#  ['무슬림 테러 범 히잡 손 프랑스 식당'],
#  ['전문 기자 칼럼 여러분 이웃 아파트'],
#  ['중국 판 살인 추억 년 만 범인'],
#  ['김철중 생로병사 충격 사달 나 사람 몸'],
#  ['데스크 친 박 타령'],
#  ['최재천 자연 문화 고령 저출산'],
#  ['트위터 트럼프 트위터'],
#  ['서지문 뉴스 책 키니 여인'],
#  ['윤희영 힐러리 트럼프 네 황제 히틀러'],
#  ['동남아 지카 비상'],
#  ['발언 대 좌절 전국 기능 대회'],
#  ['정부 북 테러 경고'],
#  ['문화재청 복원 반대 자문 위원 교체'],
#  ['한마디 군인 경찰 에어컨 것'],
#  ['내년 완공 월 정교 국적 불명 다리'],
#  ['눈물 반 기름 반 하나 둘 문 주유소'],
#  ['년 전 모습 채 궁궐 복원 사극 세트 장 얘기'],
#  ['미 대선 토론 달 열공 클린턴 즉흥 트럼프'],
#  ['조선 트로트 가수 전성기'],
#  ['팔 저주 라미란'],
#  ['무릎 마음'],
#  ['박인비 오른손 왼손 깁스'],
#  ['스타 요람 허정구 배 골프 오늘 개막'],
#  ['허재 감독 농구 대표 팀 튀니지 평가전 승리'],
#  ['나이 선배 심정'],
#  ['원성진 제 결승 최종 결판'],
#  ['삼 성화 재배 일 고양 개막'],
#  ['회 배 조선일보 기왕 전 이동훈 쾌승'],
#  ['괴력 여자 토르 주 만 세계 신'],
#  ['리우 실패 육상연맹 생존 차원 개혁 추진'],
#  ['오늘 경기 년 월 일'],
#  ['손흥민 독일 볼프스부르크 이적'],
#  ['오승환 등판 공 속도'],
#  ['소년 도전 계속'],
#  ['일사일언 음악 죄'],
#  ['팔 면봉 민주 추미애 대표 첫날 정체 지지층 결집 행보 외'],
#  ['패륜 세상 여든 나'],
#  ['제 편곡 은지 가요'],
#  ['소리'],
#  ['만화 우리 가족 얘기'],
#  ['아베 마리오 효과 지지율 장기 집권 가시'],
#  ['중관 광객 일 쇼핑 스타일 눈요기 귀국 뒤 해외 직구'],
#  ['뇌 운동 그때 기억'],
#  ['리빙 포인트 오이 마사지'],
#  ['간염 관리 구멍 만 명 치료'],
#  ['러시아 녹용 홍삼 등 가지 재료 년 노하우'],
#  ['의료 독과점 소비자 권리 보호 헌재 판결 인 개 소법'],
#  ['스테로이드 사용 바늘 신경 자극 조직 손상 출혈 감염 등 위험'],
#  ['찬성 영리 목적 네트워크 병원 의료 질 저하 우려 반대 의료 접근 사회 경제 비용'],
#  ['보청기 구입 땐 가격 사양 지속 피팅 상담 중요'],
#  ['천사 백의 천사'],
#  ['의료인 임신 순번제 인권 침해'],
#  ['저소득층 노인 무릎 인공 관절 수술 지원 건강 노년 선물'],
#  ['진피 콜라 젠 미간 주름 자연'],
#  ['자가 지방 이식 줄기세포 생착률 볼륨'],
#  ['수능 수험 보약 피'],
#  ['카테 터 특수 신경 치료 병행 재발 디스크 문제'],
#  ['당뇨 환자 위 절제술 우회술 치료 효과'],
#  ['미용 레이저 시술 치과 의사 가능'],
#  ['플라자 한국 농촌 경제 연구원 현장 토론회 개최 외'],
#  ['부음 박미자 씨 별세 외'],
#  ['인사 미래 창조 과학부 외'],
#  ['뮤지컬 전업 년'],
#  ['양창호 해양 수산 개발 원장'],
#  ['오바마 부부 러브 스토리 영화 관객 호평'],
#  ['고려대 교우회 억 장학금 수여식'],
#  ['영 총리 인생 애장품 구두'],
#  ['세계 볼트 통신사 속 책임자'],
#  ['영화 마션 가상 화성 무사 귀환'],
#  ['국제 지구 과학 올림피아드 종합 위'],
#  ['이익현 법제 연구 원장'],
#  ['최기영 독립 기념관 학술'],
#  ['구린내 맛 연잎 고추장 별미'],
#  ['국내 유일 꽃 게장 특허 자연 숙성 양조간장 맛'],
#  ['찰보리 발효 전통 증류 식 소주 뒷맛 숙취'],
#  ['식 섬유 수제 초코파이 바나나맛 제품 출시'],
#  ['신비 약초 와송 추출물 함유 아토피 탈모 예방'],
#  ['색소 대신 울금 싯 잎 가루 첨가 맛 건강'],
#  ['주문 다음 날 목장 가공 유화제 합성 향료'],
#  ['일본 제품 우수 농진청 품질 확인'],
#  ['떡 빵 동시 식사 간식거리 제격'],
#  ['청 보리 사료 볏짚 한우 유통 단계 백화점 렴'],
#  ['멥쌀 싯 잎 동부 자연 맛 화학 첨가물 웰빙 식품'],
#  ['온천 년 온천 안산 신길 온천 역'],
#  ['대림동 개벽 중국 강남'],
#  ['전교조 민주 상실 노조 설립 움직임'],
#  ['군 핵 추진 잠수함 도입 실무 검토'],
#  ['수영 전 국가 대표 만취 차 난동'],
#  ['진주 리 모델링 중 지붕 붕괴 매몰 인부 명 중 명 구조'],
#  ['복수 지원 회 확대 면접 전형 실시'],
#  ['일반 전형 면접 기회 확대 학생 부우 수자 신설'],
#  ['줄기세포 재생 융합 미래 자동차 공학 신설'],
#  ['국방 디지털 융합 학과 합격 입학금 수업료 면제'],
#  ['학교 추천 전형 학생 부 서류 평가'],
#  ['전형 간 중복 지원 가능 수능 최저 학력 기준 폐지'],
#  ['학생 부 예체능 학생 부종 합전 명 선발'],
#  ['학생 부종 합전 사범 지원자 교사 추천서 필요'],
#  ['융합 학부 입학생 전원 등록금 장학금 혜택'],
#  ['모집 단위 수능 최저 학력 기준 적용'],
#  ['평생 학습 자전 신설 저소득층 전형 확대'],
#  ['학생 종합 전형 미술 계열 실기'],
#  ['교과 성적 우수 자전 학생 부 반영'],
#  ['인문 자연 계열 한국사 등급 이내'],
#  ['적성 검사 중심 전형 폐지 일반 재전 확대'],
#  ['학부 운항 연계 전공 이수 조종사 꿈 실현'],
#  ['과학 특별 전형 국외 고교 출신 지원 가능'],
#  ['사회 복지 학과 신설 의예과 모집 인원'],
#  ['인문 사회 자연 계열 학생 부 성적 반영'],
#  ['융합 특성 화자 유전 공학부 신설 수능 기준 완화'],
#  ['소프트웨어 융합 대학 명 선발'],
#  ['수시 명 선발 간호학 일반 전형 변경'],
#  ['일반 학생 전형 수능 최저 학력 기준 폐지'],
#  ['우리 성공 열쇠 남 면접 준비 남 자소'],
#  ['교과 우수 자전 신설 교과 명'],
#  ['예체능 실기 전형 학생 부 실기'],
#  ['적성 우수 자전 명 명 선발'],
#  ['학생 부교 면접 전형 단계 교과 단계 면접'],
#  ['학생 부종 합전 전년 대비 확대'],
#  ['입학 정원 모집 수능 최저 학력 폐지'],
#  ['면접 예상 질문 가상 면접 논술 대학 제공 자료'],
#  ['학생 부종 합전 면접 자기 소개서'],
#  ['자연 계열 논술 변별력 서술 문항'],
#  ['학생 부교 전형 추천서 필요'],
#  ['화장품 학 전공 신설 큐레이터 학과 신규 모집'],
#  ['일부 학생 부교 종합 전형 간 중복 지원 금지'],
#  ['국어 문학 수록 작품 중심 공부 영어 다의어 등 어휘 집중'],
#  ['학생 부종 합전 서울 글로벌 캠퍼스 명 선발'],
#  ['수능 경쟁력 내신 등급 학생 부위 주전 최상위 도전 수능 자신 내신 등급 적성 고사 전형 고려'],
#  ['교과서 교재 중심 논술 고사 출제'],
#  ['논술 전형 내신 성적 제외 성실 평가'],
#  ['적성 고사 전형 인문 자연 계열 통합 문제 출제'],
#  ['적성 추천 전형 학생 부 적성 고사'],
#  ['학생 부종 합전 내 복수 지원 불가'],
#  ['학생 부위 주전 선발 비율 확대'],
#  ['학생 부 종합 일반 단계 수능 최저 학력 적용'],
#  ['동일 학부 내 트랙 구분 지원 가능'],
#  ['대입 수시 입학 전형 숭실 대 홍 익대'],
#  ['학교장 추천 논술 전형 추천 가능 인원 확대'],
#  ['대입 수시 입학 전형 동아 대 순천 향대'],
#  ['학생 종합 전형 면접 고사 서류 평가'],
#  ['미용 특기 자전 학생 부 성적'],
#  ['중국어 한마디 기운'],
#  ['입 일본어 계획 엉망'],
#  ['신문 실용 자 기간 기간'],
#  ['스피킹 영어'],
#  ['초 중교 청소년 자격증 취득 학력 인정'],
#  ['본지 기자 카톡 통째 보도 위법 행위 수사'],
#  ['감찰관 본지 기자 압수수색 병우 수석 집 사무실 제외'],
#  ['땅 땅 오늘 판결 농약 사이다 명 사상 대법 할머니 무기 징역'],
#  ['신고 김영란 법 출동'],
#  ['땅 땅 오늘 판결 공원 나무 개인 정원 건설사 회장 집유 년'],
#  ['본사 송희영 주필 보직 해임'],
#  ['줄 뉴스 열 차 사고 사망자 년 간 명 외'],
#  ['수학 정석 발행 년 만 권 에베레스트 개 높이'],
#  ['건 포상금 억 란 파라 섰다'],
#  ['기초 수급 가구 무료 태양광 미니 발전소'],
#  ['만 원 만 원'],
#  ['통일 펀드 동참'],
#  ['추미애 소통 이정현 왕 선배'],
#  ['민주 사무총장 안규백 정책 위 의장 윤호중'],
#  ['온라인 당원 위세 친문 의원'],
#  ['친문 기세 문재인 서울 컴백 대선 액셀'],
#  ['이석수 감찰관 사표'],
#  ['우수 석 특감 상황 용납'],
#  ['안보 건국절 보수 결집 여'],
#  ['임정 세월 호로 맞불 진보 결집 시도'],
#  ['지카 바이러스 치료 길'],
#  ['가계 빚 대책 지 일 만 부동산 과열 땐 대책'],
#  ['파산 위기 한진 해운 현대 상선 합병 생존'],
#  ['삼성 스마트 공장 멘토 중기'],
#  ['손가락 현금 인출 통장 카드 필요'],
#  ['서비스 무료 개방 업계'],
#  ['한류 소비재 불황'],
#  ['금융 사 해외 오 피스 빌딩 사냥'],
#  ['금융 사 해외 오 피스 빌딩 사냥'],
#  ['오늘 운세 월 일 화요일 음력 월 일 갑신'],
#  ['생명 일 무엇 급'],
#  ['우리 나라 수'],
#  ['고객 소비 패턴 분석 조언 지출 로봇 비서'],
#  ['화학 년 프리미엄 제품 매출 조'],
#  ['하반기 명 공채'],
#  ['뇌 운동 제목'],
#  ['오늘 날씨 년 월 일'],
#  ['여론 주목 억대 연봉 속 꽃 보직 공공 기관 감사'],
#  ['금융 월 내년 초 임기 끝 나 알짜 자리 최대 월척 국민 은행장 자리 낙하산 눈독'],
#  ['로컬 뉴스 부산시 패션 비즈 센터 건립'],
#  ['로컬 뉴스 부천시 둘째 만 원'],
#  ['김해 대구 공항 제주 공항 뒷전'],
#  ['고창 급 생태 천국'],
#  ['갯벌 청 보리밭 축제 고장 고창 만 명 듯'],
#  ['리빙 포인트 김치 신맛'],
#  ['부음 조국 시조 시인 정완영 별세 외'],
#  ['개학 철 눈병 주의보'],
#  ['보상 길 원주 간염 집단 피해자 치료비'],
#  ['남쪽 태풍 폭염'],
#  ['통일 펀드 동참'],
#  ['건설사 만 원 뒷돈 김맹곤 김해 시장 구속'],
#  ['검 특별 수사 팀 병우 고발 시민 단체 대표 조사'],
#  ['담배 사 공개 수배'],
#  ['대우 조선 기술 바 에너지 사 억 투자'],
#  ['리모 델 공사 중 지붕 명 사망'],
#  ['신 길 검찰'],
#  ['땅 땅 오늘 판결 매장 음악 무단 롯데 이마트 억 원 배상'],
#  ['사설 민주 강경 추 대표 체제 김종인 체제 속임수'],
#  ['땅 땅 오늘 판결 중 제자 성관계 학원 강사 법원 성적 학대 집유 년'],
#  ['사설 전기료 체계 거 불합리'],
#  ['불법 주정차 벌금 만 원 최고 만 원'],
#  ['사설 일 통화 스와프 재개 위기 방파제'],
#  ['조선 칼럼 년 건국 이 이유'],
#  ['견인 지역 서울 불법 주정차 손실 조 억'],
#  ['만물상 구봉서'],
#  ['태평 사람 값 나라'],
#  ['살롱 진주 냉면'],
#  ['조선 주중 하이라이트 정두언 김유정 이것 정치 외'],
#  ['특파원 칼럼 돈 선거 미 대선 한국식 선거 공영제'],
#  ['알 립니 소프트 뱅크 매출 조 원 손정 회장 선제 경영'],
#  ['데스크 빚 집'],
#  ['법 사회 수사 중 자살'],
#  ['경주 신라 왕경 복원 사업 년 조 억 투입'],
#  ['발언 대 평창 올림픽 대회장 밖 정비 필요'],
#  ['관광 상품 속도전 왕릉 건 범죄'],
#  ['가슴 시 그네'],
#  ['연내 공공 기관장 명 낙하산 암투'],
#  ['직원 희생 요구 정피 관 피아 인사 파티 하나'],
#  ['대책 효과 부동산'],
#  ['조선 할머니 제안'],
#  ['아빠 우산 때문 벌 딸 이'],
#  ['선수 김준 우승'],
#  ['회 배 조선일보 기왕 전 종반 경영 술'],
#  ['스포츠 브리핑 귀화 선수 바이애슬론 메달'],
#  ['억 원 벤치 신세 손흥민 독일 유턴'],
#  ['전북 경기 무패 행진'],
#  ['중 축구 월 일 상암 상륙작전 만 명 원정 응원 전술 예고'],
#  ['일 야구 오타니 호 홈런'],
#  ['로사리오'],
#  ['일사일언 정승 나무 꽃 때'],
#  ['팔 면봉 누리 전남 출신 대표 민주 대구 출신 대표 외'],
#  ['그리스 밤 한국 코리아 브라보'],
#  ['베르디 노래'],
#  ['리뷰 무대 위 명 천둥 울림'],
#  ['금주 공연 이유 선택 라 스칼라 오케스트라 합창단 외'],
#  ['한국 찰리 채플린 영원 희극 나라'],
#  ['소설 과학'],
#  ['죄 벌 무대 도스토옙스키 조각상'],
#  ['왕릉 개 이상 년 내 경주 사업'],
#  ['도착 걸 용서 구조 대원 소녀 관 위 작별 편지'],
#  ['음식 콧대 파리 배달 앱'],
#  ['트럼프 반전 참모 구설수'],
#  ['천취안궈 내년 중 정치 국원 유력'],
#  ['아프리카 일 아베 총리 년 조 원 투자 것'],
#  ['바티칸 중국 수교 분위기'],
#  ['최보식 사람 아파트 관리 회사 허수아비 관리 소장 임명'],
#  ['미 북수 역 정보 공유 대잠 작전 강화'],
#  ['전문대 특집 한류 세계 글로벌 케이 컬처 센터 설립'],
#  ['전문대 특집 취업 년 전통 보건 의료 대학'],
#  ['교사 고유 침범 학생 부 조종 학교 밖 검은손'],
#  ['바둑 두뇌 훈련 애니메이션 강의 프로 대국'],
#  ['뇌교육 문화 휴먼 서비스 분야 특화 실용 교육 장점'],
#  ['뇌 교육 심신 스트레스 완화 삶 질 향상'],
#  ['미국식 조기 영어 학습 프로그램 공부'],
#  ['전문대 특집 실무 중심 교육 취업 프로그램 적극 운영'],
#  ['에듀 테크 스타트업 기업 성공 지원 것'],
#  ['알 립니 수능 단기 완성 학습 프로그램 대성 파이널 신청 외'],
#  ['전문대 특집 학생 부 총점 범위 내 출결 가산점 부여'],
#  ['알 립니 국토 교통부 장관 학교 단체상 수여 국토 사랑 글짓기 대회 개최'],
#  ['중국어 한마디 규칙 생활'],
#  ['입 일본어 요령 체득'],
#  ['신문 실용 자 수묵 수묵'],
#  ['스피킹 영어'],
#  ['안보리 대북 규탄 성명 이번 중국 찬성'],
#  ['친문 독식 온라인 파워 말조심 의원'],
#  ['정권 교체 추 다르크 친문 대리인'],
#  ['추미애 친문 비문 말 균형추 것'],
#  ['민주 최고 위원 명 프로필'],
#  ['민주 전대 날 세력 지피 국민 당'],
#  ['친문 여권 결집'],
#  ['추미애 사드 반대 당론 정진석 사드 배치 당론'],
#  ['당원 조직 친문 완성'],
#  ['대구 출신 여성 야당'],
#  ['대표 동갑 년 개띠 전성시대'],
#  ['남경필 정계 개편 난 누리 승부'],
#  ['김종인 페이스북 열자 김재원 호 댓글'],
#  ['매주 꽃 세팅 수거 참여 기업 사회 공헌 참여 가능'],
#  ['선 취업 후 진학 일 학습 병행 맞춤 인재 신채 문화'],
#  ['체력 인증 센터 방문 땐 국민 체력'],
#  ['서포터 즈 개국 유학생 한국 관광 세계'],
#  ['꽃 정기 구독 시대'],
#  ['특별기 서류 상공 지원 신청'],
#  ['고급 소가죽 수제 세련 가을'],
#  ['매출 배 부채 억 지방 공기업 전국 위'],
#  ['세 가입 의료진 전화 상담 등 고령자 맞춤 서비스'],
#  ['고객 소비 패턴 분석 조언 지출 로봇 비서'],
#  ['수수료 실시간 매매 서비스 보수 포트폴리오 차등 적용'],
#  ['뱅킹 서비스 은행 업무 대부분 현장 처리'],
#  ['수익 해지 환급금 보증 종신 보험'],
#  ['투자자 생애 주기 최적 자산 배분 전략 제공'],
#  ['업계 최초 홈페이지 채권 매매 서비스'],
#  ['은퇴 설계 생각 때 시기'],
#  ['변호사 선임 비용 벌금 등 보장 운전자 보험'],
#  ['은퇴 이후 수입 지출 최신 제도 반영 산출 대 은퇴 점검'],
#  ['평생 설계 통장 우대 서비스 연금 시뮬레이션 영업 점 은퇴 설계 상담 가능'],
#  ['보험료 중증 치매 간병 등 보장 확대 보험 출시'],
#  ['유병 장수 시대 연금 의료비 심사 보험 가입'],
#  ['유망 배당주 국공 투자 중 장기 수익 추구'],
#  ['넥 년 만 대 세계 연간 차 판매량 달 듯'],
#  ['넥 년 만 대 세계 연간 차 판매량 달 듯'],
#  ['뉴스 사람 전기 이삿짐 서민 전기료 연좌제'],
#  ['가전 모바일 자동차 소통'],
#  ['현대차 잠정 합의 노조원 반대 일 만 부결'],
#  ['정세균 의장 개회사 사심 사과'],
#  ['여 농성 박지원 우리 짓 야당'],
#  ['올림픽 볼트 패럴림픽 스미스'],
#  ['올림픽 패럴림픽 도시 건 년 서울 대회 처음'],
#  ['사드 국 목표 이유 중 설득 박 대통령'],
#  ['물 북 명 사망 등 인명 피해 속출'],
#  ['미 최신 핵 잠수함 월 태평양 배치'],
#  ['손학규 죽음 각오 나 하산 선언'],
#  ['미래 부 갑 간부 직위 해제'],
#  ['유치원 버스 터널 속 전복 안전벨트 뻔'],
#  ['감염자 스케일링 때 의자 비닐 인격 침해'],
#  ['기형아 출산 뇌 발달 저해 술병 명시'],
#  ['정운호 금품 부장 판사 구속'],
#  ['검 강만수 특혜 대출 정황 포착'],
#  ['구직자 번 채용 서류 반환 거부'],
#  ['정명훈 도쿄 명예 음악 감독'],
#  ['노세영 서울 학대 총장 취임'],
#  ['인사 미래 창조 과학부 외'],
#  ['인사 미래 창조 과학부'],
#  ['인사 국토 교통부'],
#  ['인사 해양수산부'],
#  ['인사 금융 위원회'],
#  ['우즈베크 년 철권 통치 카리모프 대통령 별세'],
#  ['외국인 주민 빚 송편'],
#  ['태풍 남 테 영향 월 첫째 주말 남해안 비'],
#  ['부고 강승규 모친상 외'],
#  ['부고 강승규 모친상'],
#  ['부고 권대혁 경혁 귀현 귀희 정현 부친상 종우 고은아 시 부상'],
#  ['부고 김상현 주현 동현 부친상'],
#  ['부고 김선호 민호 모친상'],
#  ['부고 김영식 별세'],
#  ['부고 박건창 건순 모친상'],
#  ['부고 박택상 응상 부친상 고재구 장인상'],
#  ['부고 송두 별세 김대영 민 녕 영애 영숙 영자 영명 모친상 최융 호 손명원 허광수 정몽준 장모 정다미 시 모상'],
#  ['부고 이영해 별세'],
#  ['부고 장삼 대성 모친상 김규성 남하 룡 장모'],
#  ['인사 국세청 사무관 승진 인사'],
#  ['유창근 년 만 컴백 현대 상선 사장 내정'],
#  ['경제 인사 서민 금융 진흥 원 초대 원장 김윤영 씨'],
#  ['지표 경제 월 일'],
#  ['삼성전자 퀀텀 닷 차세대 시장 주도'],
#  ['전자 아마존 스마트 홈 사업 협력'],
#  ['국내 인공지능 왓슨 암 진단'],
#  ['삼성물산 패션 브랜드 구호 내년 미 상륙'],
#  ['사고 위험 도로 손'],
#  ['한화 생명 우리 은행 지분 인수 참여 검토'],
#  ['뉴스 단신 김재철 동원 회장 보훈 처 감사패 외'],
#  ['경제 인사 한국 거래소'],
#  ['선수 슈틸리케 엔트리 명 불안 모험'],
#  ['오늘 경기 월 일 프로 야구 외'],
#  ['내일 경기 월 일 프로 야구 외'],
#  ['한미 장타 여왕 박성현 전날 부진 공동 선두'],
#  ['오늘 키워드 년 연속 만 관중'],
#  ['머리 염색 남자 월드컵 남미 예선'],
#  ['독사 위기 여자 배구'],
#  ['김현수 적응력'],
#  ['책 향기 카메라 소멸 도구 우리'],
#  ['책 향기 파리 노숙 엘리트 법관 친구'],
#  ['책 향기 시 한센병 할머니 눈물'],
#  ['책 향기 독창 죽음 앞 그 태도'],
#  ['책 향기 청계천 책방 나이 뭣 디'],
#  ['책 싸이 퍼 외'],
#  ['책 향기 술 술 책 피시'],
#  ['책 향기 단위 금속 과학 뼈대 탐구'],
#  ['책 향기 알랭 드 보통 말 결혼 사랑 기술'],
#  ['책 향기 마더 테레사 세상 가슴'],
#  ['어린이 책 누나 숨바꼭질'],
#  ['책 향기 자 서평 여자 게 외'],
#  ['글로벌 기획 테러 차별 바리케이드 식 원시 대응'],
#  ['글로벌 기획 뉴욕 비극 현장 부활 도약 상징 변신'],
#  ['토요 논문 무료 공개 세계 오픈 액세스 혁명'],
#  ['조성하 여행 전문 기자 동행 아프리카 말'],
#  ['오늘 운세 월 일'],
#  ['오늘 운세 월 일'],
#  ['동아 광장 최진석 이익'],
#  ['김창기 음악상 사랑 삶 가요'],
#  ['굿바이 서울 김은홍 요리사 자격'],
#  ['횡설수설 권순활 노블레스 오 블리 주 서경배 과학 재단'],
#  ...]

# %% [markdown]
# ## Training
# Topic modeling : Latent Dirichlet allocation (LDA)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from time import time

# %%
vectorizer = TfidfVectorizer(lowercase=False)
title_flat = [item for sublist in title for item in sublist]
x_list = vectorizer.fit_transform(title_flat)
x_list
# Out:
# <3068x5904 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16204 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Topic Modeling
# Latent Dirichlet Allocation (LDA)

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
t0 = time()
lda = LatentDirichletAllocation(n_topics=15, max_iter=5, n_jobs=-1)
lda.fit(x_list)
print("Done in %0.3fs." % (time() - t0))
# Out:
# Done in 6.378s.

# %%
feature_names = vectorizer.get_feature_names()
print_top_words(lda, feature_names, 20)
# Out:
# Topic #0:
# 경제 송희영 시민 김진태 주필 친문 문제 의료 사랑 지표 인사 화제 현장 안희정 어린이 분양 그룹 공사 인생 대선
# Topic #1:
# 인사 미래 조선일보 조선 병원 서울 대학 기업 시대 일본 예산 청와대 최고 발생 경영 뉴스 종합 위안부 단신 회장
# Topic #2:
# 청년 청소년 공개 일자리 토크 연속 발견 자리 생명 비상 지카 위원 총리 무엇 인정 천억 담배 대신 아이 아시아
# Topic #3:
# 전형 수시 전략 학생 대입 필승 가능 확대 지원 신설 선발 올해 영화 개월 인천 면접 적성 모집 공감 고사
# Topic #4:
# 대학교 국회 추경 부산 청문회 금융 올림픽 운동 희망 비판 처리 음악 의장 정책 발언 민주 장인상 정의 정기 부고
# Topic #5:
# 수능 여성 산업 최저 사진 사망 야당 누구 기준 출신 폭로 특별 적용 독립 기사 아침 캠프 부회장 이정현 충북
# Topic #6:
# 소식 추석 단독 내년 트럼프 시장 동정 정치 정부 마음 역사 폭발 주택 공급 호세프 감동 공항 탄핵 선물 성장
# Topic #7:
# 사회 공헌 검찰 구조 환자 국민 추진 수사 과학 피해자 콜레라 마을 교육 롯데 법원 이상 공부 국제 간염 조정
# Topic #8:
# 병우 사드 부고 별세 운세 오늘 모친상 책임 언론 한가위 이석수 사표 반대 사고 누리 배치 이번 경찰 사설 남도
# Topic #9:
# 포토 날씨 지역 나라 우리 정보 우수 정상 대통령 해외 회담 폭탄 불법 노동 사드 강화 오늘 방송 아기 테슬라
# Topic #10:
# 야구 학교 프로 폭염 관리 한진 부동산 한국 조사 해운 현대 결정 국내 전국 자유 우승 역대 도입 하나 법정
# Topic #11:
# 생각 세월 사업 전자 김재수 감사 경주 세트 인상 디자인 생활 김영훈 위원장 장관 장학금 기록 판매 유럽 임금 때문
# Topic #12:
# 사람 해운 한진 한겨레 뉴스룸 노동자 사설 금리 관리 물류 그림판 중국 축구 의혹 증권 신문 법정 사과 마지막 피해
# Topic #13:
# 경기 오늘 노트 여자 배터리 갤럭시 확정 삼성 삼성전자 채널 리콜 세계 대법 교수 공장 진출 논란 안전 시장 한류
# Topic #14:
# 세상 부친상 부고 재단 가슴 당신 통일 부상 서울시 소년 운명 재벌 이름 펀드 동참 소녀 동시 출범 살인 소리

# %% [markdown]
# ## Result
# 1. Model Selection
# 2. Preprocessing
# 3. Feature Engineering
# 4. Parameter Tuning
# 5. Score Function
